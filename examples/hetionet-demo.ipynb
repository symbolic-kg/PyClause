# %%
# to run jupyter from a conda env install
# 'conda install nb_conda_kernels'
# open notebbok and ge to Kernel/Change Kernel and select env

# %%
from os import path
from c_clause import QAHandler, Loader, RulesHandler, PredictionHandler
import numpy as np
from clause import Options, Learner
from clause.util.utils import get_base_dir

# %% [markdown]
# ### Preparation

# %%
# ensure that the data is downloaded and the hetionet folder is put into
# PyClause/data/

train = f"{get_base_dir()}/data/hetionet/train.txt"
filter_set = f"{get_base_dir()}/data/hetionet/valid.txt"
test_set = f"{get_base_dir()}/data/hetionet/valid.txt"
opts = Options()
exp_dir = f"{get_base_dir()}/local/paper-demonstration"

# %%
# The orginal data comes with entity/relation identifier like so
# (Gene::9282,  GiG, Gene::9441)
# PyClause allows to substitute these with a more readable format
# after the data and rules are loaded
# we do this here and it is used later

entity_names_f = f"{get_base_dir()}/data/hetionet/entity_strings.txt"

entity_names = {}
with open(entity_names_f, 'r') as file:
    for line in file:
        key, value = line.strip().split('\t')
        entity_names[key] = value

relation_names_f = f"{get_base_dir()}/data/hetionet/relation_strings.txt"
relation_names = {}
with open(relation_names_f, 'r') as file:
    for line in file:
        key, value = line.strip().split('\t')
        relation_names[key] = value

# %% [markdown]
# ### Learn rules for all relations and separately for the target relation

# %%
rules_target_rel = path.join(exp_dir, "anyburl-rules-target.txt")
rules_all = path.join(exp_dir, "anyburl-rules-all.txt")

# %%
# you don't need to run this again
# rulesets are provided

if False:
    # learn rules for all relations
    opts.set("learner.mode", "anyburl")
    opts.set("learner.anyburl.time", 1000)
    learner = Learner(options=opts.get("learner"))
    learner.learn_rules(path_data=train, path_output=rules_all)

    # learn rules for target relation
    opts.set("learner.mode", "anyburl")
    opts.set("learner.anyburl.time", 1000)
    opts.set("learner.anyburl.raw.SINGLE_RELATIONS", "CtD")
    learner = Learner(options=opts.get("learner"))

# %% [markdown]
# ## Analyze the general KG (rulset for all relations)

# %%
# load data (construct a loader with default options)
# loads more than 1mio triples
loader_1 = Loader(options={})
loader_1.load_data(train)
# Out:
# Loading triples...
# Loaded triples.

# %%
# load the rulset that learned rules for all relations
# load only rules with constants
opts.set("loader.load_u_d_rules", False)
opts.set("loader.load_u_c_rules", True)
opts.set("loader.c_min_support", 20)
opts.set("loader.load_u_xxd_rules", False)
opts.set("loader.load_u_xxc_rules", False)
opts.set("loader.load_zero_rules", False)
opts.set("loader.load_b_rules", False)

loader_1.set_options(options=opts.get("loader"))
# load rules with original relation string representation
loader_1.load_rules(rules=rules_all)
# substitute relations/entities in loader index with more readable strings
loader_1.replace_rel_strings(relation_names)
loader_1.replace_ent_strings(entity_names)
# Out:
# Setting option load_zero_rules to: False
# Setting option z_weight to: 0.1
# Setting option z_num_unseen to: 5
# Setting option z_min_support to: -1
# Setting option z_min_preds to: -1
# Setting option z_min_conf to: 0.0001
# Setting option load_u_c_rules to: True
# Setting option c_num_unseen to: 5
# Setting option c_min_support to: 20
# Setting option c_min_preds to: -1
# Setting option c_min_conf to: 0.0001
# Setting option c_max_length to: -1
# Setting option load_b_rules to: False
# Setting option b_max_branching_factor to: -1
# Setting option b_num_unseen to: 5
# Setting option b_min_support to: -1
# Setting option b_min_preds to: -1
# Setting option b_min_conf to: 0.0001
# Setting option b_max_length to: -1
# Setting option load_u_d_rules to: False
# Setting option d_weight to: 0.01
# Setting option d_max_branching_factor to: -1
# Setting option d_num_unseen to: 5
# Setting option d_min_support to: -1
# Setting option d_min_preds to: -1
# Setting option d_min_conf to: 0.0001
# Setting option d_max_length to: -1
# Setting option load_u_xxc_rules to: False
# Setting option xxc_num_unseen to: 5
# Setting option xxc_min_support to: -1
# Setting option xxc_min_preds to: -1
# Setting option xxc_min_conf to: 0.0001
# Setting option load_u_xxd_rules to: False
# Setting option xxd_num_unseen to: 5
# Setting option xxd_min_support to: -1
# Setting option xxd_min_preds to: -1
# Setting option xxd_min_conf to: 0.0001
# Loading rules from /home/patrick/Desktop/PyClause/local/paper-demonstration/anyburl-rules-all.txt
# ...parsed 1000000 rules
# Loaded 435279 rules.

# %%
## display the strongest rules with constants
rules = loader_1.get_rules()
rules = [line.split("\t") for line in rules]
rules.sort(key=lambda in_list: in_list[2], reverse=True)
num_rules  = 10000
for i in range(num_rules):
    if "Side" in rules[i][3]:
        print(rules[i][0], rules[i][1],rules[i][2], rules[i][3])
# Out:
# 48 48 1.000000 Compound-causes-Side-Effect(Potassium Iodide,Y) <= Compound-causes-Side-Effect(Potassium Canrenoate,Y)
# 222 222 1.000000 Compound-causes-Side-Effect(Levobupivacaine,Y) <= Compound-causes-Side-Effect(Bupivacaine,Y)
# 208 208 1.000000 Compound-causes-Side-Effect(Atropine,Y) <= Compound-causes-Side-Effect(Hyoscyamine,Y)
# 108 108 1.000000 Compound-causes-Side-Effect(Fondaparinux sodium,Y) <= Compound-causes-Side-Effect(Sodium lauryl sulfate,Y)
# 204 204 1.000000 Gene-participates-Biological_Process(X,nucleobase-containing small molecule metabolic process) <= Gene-participates-Biological_Process(X,nucleoSide_triphosphate metabolic process)
# 39 39 1.000000 Gene-participates-Biological_Process(X,purine ribonucleoSide_triphosphate metabolic process) <= Gene-participates-Biological_Process(X,ATP generation from ADP)
# 38 38 1.000000 Gene-participates-Biological_Process(X,purine nucleoSide_monophosphate metabolic process) <= Gene-participates-Biological_Process(X,glycolytic process)
# 30 30 1.000000 Compound-causes-Side-Effect(X,Headache) <= Compound-causes-Side-Effect(X,Breast neoplasm)
# 39 39 1.000000 Compound-causes-Side-Effect(Calcium Chloride,Y) <= Compound-causes-Side-Effect(Calcium Gluceptate,Y)
# 30 30 1.000000 Compound-causes-Side-Effect(Ethinyl Estradiol,Y) <= Compound-causes-Side-Effect(Drospirenone,Y)
# 26 26 1.000000 Compound-causes-Side-Effect(X,Body temperature increased) <= Compound-causes-Side-Effect(X,Red blood cell sedimentation rate increased)
# 25 25 1.000000 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Malignant melanoma)
# 272 272 1.000000 Gene-participates-Biological_Process(X,glycosyl compound metabolic process) <= Gene-participates-Biological_Process(X,purine ribonucleoSide_metabolic process)
# 124 124 1.000000 Gene-participates-Biological_Process(X,nucleoSide_phosphate biosynthetic process) <= Gene-participates-Biological_Process(X,purine nucleotide biosynthetic process)
# 34 34 1.000000 Compound-causes-Side-Effect(X,Rash) <= Compound-causes-Side-Effect(X,Injection site inflammation)
# 138 138 1.000000 Compound-causes-Side-Effect(X,Cystitis) <= Compound-causes-Side-Effect(X,Cystitis noninfective)
# 116 116 1.000000 Gene-participates-Biological_Process(X,glycosyl compound biosynthetic process) <= Gene-participates-Biological_Process(X,nucleoSide_biosynthetic process)
# 26 26 1.000000 Compound-causes-Side-Effect(X,Asthenia) <= Compound-causes-Side-Effect(X,Abscess periodontal)
# 23 23 1.000000 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Breast discharge)
# 44 44 1.000000 Gene-participates-Biological_Process(X,nucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,purine ribonucleoSide_triphosphate biosynthetic process)
# 443 443 1.000000 Gene-participates-Biological_Process(X,nucleoSide_phosphate metabolic process) <= Gene-participates-Biological_Process(X,nucleotide metabolic process)
# 39 39 1.000000 Compound-causes-Side-Effect(X,Respiratory failure) <= Compound-causes-Side-Effect(X,Hypoventilation)
# 44 44 1.000000 Gene-participates-Biological_Process(X,glycosyl compound metabolic process) <= Gene-participates-Biological_Process(X,purine ribonucleoSide_triphosphate biosynthetic process)
# 450 450 1.000000 Gene-participates-Biological_Process(X,organophosphate metabolic process) <= Gene-participates-Biological_Process(X,nucleoSide_phosphate metabolic process)
# 29 29 1.000000 Compound-causes-Side-Effect(X,Infection) <= Compound-causes-Side-Effect(X,Miliaria)
# 511 511 1.000000 Compound-causes-Side-Effect(Epirubicin,Y) <= Compound-causes-Side-Effect(Doxorubicin,Y)
# 35 35 1.000000 Compound-causes-Side-Effect(X,Body temperature increased) <= Compound-causes-Side-Effect(X,Enteritis)
# 324 324 1.000000 Gene-participates-Biological_Process(X,nucleobase-containing small molecule metabolic process) <= Gene-participates-Biological_Process(X,nucleoSide_metabolic process)
# 26 26 1.000000 Gene-participates-Biological_Process(X,glycosphingolipid metabolic process) <= Gene-participates-Biological_Process(X,ganglioSide_metabolic process)
# 149 149 1.000000 Compound-causes-Side-Effect(X,Muscle spasms) <= Compound-causes-Side-Effect(X,Cramps of lower extremities)
# 511 511 1.000000 Compound-causes-Side-Effect(Doxorubicin,Y) <= Compound-causes-Side-Effect(Epirubicin,Y)
# 61 61 1.000000 Gene-participates-Biological_Process(X,purine nucleoSide_monophosphate metabolic process) <= Gene-participates-Biological_Process(X,purine nucleoSide_monophosphate biosynthetic process)
# 22 22 1.000000 Gene-participates-Biological_Process(X,heterocycle catabolic process) <= Gene-participates-Biological_Process(X,pyrimidine nucleoSide_catabolic process)
# 192 192 1.000000 Compound-causes-Side-Effect(X,Anaphylactic shock) <= Compound-causes-Side-Effect(X,Anaphylactoid reaction)
# 50 50 1.000000 Gene-participates-Biological_Process(X,carbohydrate derivative biosynthetic process) <= Gene-participates-Biological_Process(X,ribonucleoSide_triphosphate biosynthetic process)
# 28 28 1.000000 Gene-participates-Cellular_Component(X,lumenal Side_of membrane) <= Gene-participates-Cellular_Component(X,lumenal Side_of endoplasmic reticulum membrane)
# 162 162 1.000000 Gene-participates-Biological_Process(X,ribonucleoSide_monophosphate metabolic process) <= Gene-participates-Biological_Process(X,ATP metabolic process)
# 259 259 1.000000 Compound-causes-Side-Effect(Eszopiclone,Y) <= Compound-causes-Side-Effect(Zopiclone,Y)
# 20 20 1.000000 Compound-causes-Side-Effect(X,Gastrointestinal disorder) <= Pharmacologic_Class-includes-Compound(Cytochrome P450 3A4 Inhibitors,X)
# 20 20 1.000000 Gene-participates-Biological_Process(X,purine nucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,purine ribonucleoSide_bisphosphate metabolic process)
# 73 73 1.000000 Gene-participates-Biological_Process(X,nucleoSide_monophosphate biosynthetic process) <= Gene-participates-Biological_Process(X,ribonucleoSide_monophosphate biosynthetic process)
# 81 81 1.000000 Gene-participates-Biological_Process(X,nucleoSide_phosphate biosynthetic process) <= Gene-participates-Biological_Process(X,nucleoSide_monophosphate biosynthetic process)
# 52 52 1.000000 Compound-causes-Side-Effect(X,Rash) <= Compound-causes-Side-Effect(X,Hernia)
# 182 182 1.000000 Gene-participates-Biological_Process(X,nucleotide metabolic process) <= Gene-participates-Biological_Process(X,ribonucleoSide_triphosphate metabolic process)
# 57 57 1.000000 Compound-causes-Side-Effect(X,Vulvovaginal mycotic infection) <= Compound-causes-Side-Effect(X,Vaginal moniliasis)
# 222 222 1.000000 Compound-causes-Side-Effect(Bupivacaine,Y) <= Compound-causes-Side-Effect(Levobupivacaine,Y)
# 46 46 1.000000 Compound-causes-Side-Effect(X,Dizziness) <= Compound-causes-Side-Effect(X,Prostatic disorder)
# 87 87 1.000000 Gene-participates-Biological_Process(X,nucleoSide_biosynthetic process) <= Gene-participates-Biological_Process(X,purine nucleoSide_biosynthetic process)
# 21 21 1.000000 Compound-causes-Side-Effect(X,Vomiting) <= Compound-causes-Side-Effect(X,Autonomic neuropathy)
# 77 77 1.000000 Compound-causes-Side-Effect(X,Dermatitis) <= Compound-causes-Side-Effect(X,Hypothyroidism)
# 332 332 1.000000 Compound-causes-Side-Effect(Dexmethylphenidate,Y) <= Compound-causes-Side-Effect(Methylphenidate,Y)
# 57 57 1.000000 Compound-causes-Side-Effect(X,Rash) <= Compound-causes-Side-Effect(X,Vaginal moniliasis)
# 45 45 1.000000 Compound-causes-Side-Effect(Cisatracurium Besylate,Y) <= Compound-causes-Side-Effect(Atracurium,Y)
# 26 26 1.000000 Gene-participates-Biological_Process(X,sphingolipid metabolic process) <= Gene-participates-Biological_Process(X,ganglioSide_metabolic process)
# 275 275 1.000000 Gene-participates-Biological_Process(X,nucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,purine nucleoSide_metabolic process)
# 20 20 1.000000 Compound-causes-Side-Effect(X,Dermatitis) <= Compound-causes-Side-Effect(X,Bronchopneumonia)
# 22 22 1.000000 Gene-participates-Biological_Process(X,ribonucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,pyrimidine ribonucleotide biosynthetic process)
# 21 21 1.000000 Compound-causes-Side-Effect(X,Secondary infection) <= Compound-causes-Side-Effect(X,Dermatitis perioral)
# 58 58 1.000000 Compound-causes-Side-Effect(X,Blood lactate dehydrogenase increased) <= Compound-causes-Side-Effect(X,Lactic dehydrogenase activity increased)
# 46 46 1.000000 Compound-causes-Side-Effect(X,Somnolence) <= Compound-causes-Side-Effect(X,Paranoid reaction)
# 823 823 1.000000 Compound-causes-Side-Effect(Escitalopram,Y) <= Compound-causes-Side-Effect(Citalopram,Y)
# 453 453 1.000000 Compound-causes-Side-Effect(Tretinoin,Y) <= Compound-causes-Side-Effect(Alitretinoin,Y)
# 159 159 1.000000 Compound-causes-Side-Effect(X,Dizziness) <= Compound-causes-Side-Effect(X,Abnormal vision)
# 44 44 1.000000 Compound-causes-Side-Effect(X,Depressed level of consciousness) <= Compound-causes-Side-Effect(X,CNS depression NOS)
# 138 138 1.000000 Compound-causes-Side-Effect(Levomilnacipran,Y) <= Compound-causes-Side-Effect(Milnacipran,Y)
# 38 38 1.000000 Gene-participates-Biological_Process(X,nucleoSide_triphosphate metabolic process) <= Gene-participates-Biological_Process(X,mitochondrial electron transport, NADH to ubiquinone)
# 33 33 1.000000 Compound-causes-Side-Effect(X,Dermatitis) <= Compound-causes-Side-Effect(X,Conjunctival haemorrhage)
# 62 62 1.000000 Gene-participates-Biological_Process(X,nucleobase-containing small molecule metabolic process) <= Gene-participates-Biological_Process(X,purine nucleoSide_diphosphate metabolic process)
# 25 25 1.000000 Compound-causes-Side-Effect(Caspofungin,Y) <= Compound-causes-Side-Effect(Trimetrexate,Y)
# 115 115 1.000000 Compound-causes-Side-Effect(X,Injury) <= Compound-causes-Side-Effect(X,Accidental injury)
# 36 36 1.000000 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Dizziness postural)
# 44 44 1.000000 Gene-participates-Biological_Process(X,nucleoSide_phosphate metabolic process) <= Gene-participates-Biological_Process(X,purine ribonucleoSide_triphosphate biosynthetic process)
# 28 28 1.000000 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Thrombotic thrombocytopenic purpura)
# 823 823 1.000000 Compound-causes-Side-Effect(Citalopram,Y) <= Compound-causes-Side-Effect(Escitalopram,Y)
# 204 204 1.000000 Gene-participates-Biological_Process(X,nucleoSide_phosphate metabolic process) <= Gene-participates-Biological_Process(X,nucleoSide_triphosphate metabolic process)
# 67 67 1.000000 Gene-participates-Biological_Process(X,organic cyclic compound catabolic process) <= Gene-participates-Biological_Process(X,nucleoSide_phosphate catabolic process)
# 86 86 1.000000 Compound-causes-Side-Effect(Aminophylline,Y) <= Compound-causes-Side-Effect(Theophylline,Y)
# 32 32 1.000000 Compound-causes-Side-Effect(X,Headache) <= Compound-causes-Side-Effect(X,Warmth)
# 275 275 1.000000 Gene-participates-Biological_Process(X,purine-containing compound metabolic process) <= Gene-participates-Biological_Process(X,purine nucleoSide_metabolic process)
# 29 29 1.000000 Compound-causes-Side-Effect(X,Diarrhoea) <= Compound-causes-Side-Effect(X,Memory loss)
# 69 69 1.000000 Gene-participates-Biological_Process(X,nucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,oxidative phosphorylation)
# 453 453 1.000000 Compound-causes-Side-Effect(Isotretinoin,Y) <= Compound-causes-Side-Effect(Alitretinoin,Y)
# 38 38 1.000000 Gene-participates-Biological_Process(X,purine ribonucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,glycolytic process)
# 71 71 1.000000 Compound-causes-Side-Effect(Levothyroxine,Y) <= Compound-causes-Side-Effect(Dextrothyroxine,Y)
# 33 33 1.000000 Compound-causes-Side-Effect(X,Dermatitis) <= Compound-causes-Side-Effect(X,Breast tenderness)
# 162 162 1.000000 Gene-participates-Biological_Process(X,nucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,ATP metabolic process)
# 40 40 1.000000 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Stiffness)
# 223 223 1.000000 Gene-participates-Biological_Process(X,nucleoSide_phosphate metabolic process) <= Gene-participates-Biological_Process(X,nucleoSide_monophosphate metabolic process)
# 34 34 1.000000 Compound-causes-Side-Effect(X,Dermatitis) <= Compound-causes-Side-Effect(X,Tenosynovitis)
# 44 44 1.000000 Gene-participates-Biological_Process(X,ribonucleoSide_triphosphate biosynthetic process) <= Gene-participates-Biological_Process(X,purine ribonucleoSide_triphosphate biosynthetic process)
# 40 40 1.000000 Compound-causes-Side-Effect(X,Dermatitis) <= Compound-causes-Side-Effect(X,Ejaculation disorder)
# 171 171 1.000000 Compound-causes-Side-Effect(Quinidine barbiturate,Y) <= Compound-causes-Side-Effect(Quinidine,Y)
# 249 249 1.000000 Compound-causes-Side-Effect(Dexamethasone,Y) <= Compound-causes-Side-Effect(Betamethasone,Y)
# 56 56 1.000000 Compound-causes-Side-Effect(X,Headache) <= Compound-causes-Side-Effect(X,Pneumothorax)
# 43 43 1.000000 Compound-causes-Side-Effect(Dihydroxyaluminium,Y) <= Compound-causes-Side-Effect(Glycine,Y)
# 36 36 1.000000 Compound-causes-Side-Effect(X,Musculoskeletal discomfort) <= Compound-causes-Side-Effect(X,Pyuria)
# 171 171 1.000000 Compound-causes-Side-Effect(Quinine,Y) <= Compound-causes-Side-Effect(Quinidine,Y)
# 302 302 1.000000 Compound-causes-Side-Effect(Esomeprazole,Y) <= Compound-causes-Side-Effect(Omeprazole,Y)
# 238 238 1.000000 Gene-participates-Cellular_Component(X,cell surface) <= Gene-participates-Cellular_Component(X,external Side_of plasma membrane)
# 27 27 1.000000 Gene-participates-Biological_Process(X,nucleoSide_phosphate metabolic process) <= Gene-participates-Biological_Process(X,glycolytic process through fructose-6-phosphate)
# 69 69 1.000000 Compound-causes-Side-Effect(X,Lacrimation increased) <= Compound-causes-Side-Effect(X,Lacrimation)
# 95 95 1.000000 Gene-participates-Biological_Process(X,nucleoSide_phosphate metabolic process) <= Gene-participates-Biological_Process(X,nicotinamide nucleotide metabolic process)
# 169 169 1.000000 Gene-participates-Cellular_Component(X,Side_of membrane) <= Gene-participates-Cellular_Component(X,cytoplasmic Side_of membrane)
# 301 301 1.000000 Gene-participates-Biological_Process(X,nucleobase-containing small molecule metabolic process) <= Gene-participates-Biological_Process(X,ribonucleoSide_metabolic process)
# 50 50 1.000000 Gene-participates-Biological_Process(X,ribose phosphate biosynthetic process) <= Gene-participates-Biological_Process(X,ribonucleoSide_triphosphate biosynthetic process)
# 21 21 1.000000 Compound-causes-Side-Effect(X,Dermatitis) <= Compound-causes-Side-Effect(X,Iron deficiency anaemia)
# 33 33 1.000000 Compound-causes-Side-Effect(X,Rash) <= Compound-causes-Side-Effect(X,Tetany)
# 62 62 1.000000 Gene-participates-Biological_Process(X,organophosphate metabolic process) <= Gene-participates-Biological_Process(X,purine nucleoSide_diphosphate metabolic process)
# 37 37 1.000000 Compound-causes-Side-Effect(X,Dermatitis) <= Compound-causes-Side-Effect(X,Anger)
# 60 60 1.000000 Gene-participates-Biological_Process(X,purine ribonucleoSide_monophosphate metabolic process) <= Gene-participates-Biological_Process(X,ATP synthesis coupled electron transport)
# 57 57 1.000000 Compound-causes-Side-Effect(X,Vulvovaginal candidiasis) <= Compound-causes-Side-Effect(X,Vaginal moniliasis)
# 82 82 1.000000 Compound-causes-Side-Effect(X,Abdominal pain) <= Compound-causes-Side-Effect(X,Abdominal cramps)
# 61 61 1.000000 Gene-participates-Biological_Process(X,nucleoSide_monophosphate biosynthetic process) <= Gene-participates-Biological_Process(X,purine nucleoSide_monophosphate biosynthetic process)
# 106 106 1.000000 Gene-participates-Biological_Process(X,ribonucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,ribonucleoSide_biosynthetic process)
# 21 21 1.000000 Compound-causes-Side-Effect(Telavancin,Y) <= Compound-causes-Side-Effect(Radium Ra 223 Dichloride,Y)
# 37 37 1.000000 Gene-participates-Biological_Process(X,purine nucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,purine nucleoSide_bisphosphate metabolic process)
# 208 208 1.000000 Compound-causes-Side-Effect(Hyoscyamine,Y) <= Compound-causes-Side-Effect(Atropine,Y)
# 53 53 1.000000 Compound-causes-Side-Effect(X,Dizziness) <= Compound-causes-Side-Effect(X,Neck stiffness)
# 453 453 1.000000 Compound-causes-Side-Effect(Isotretinoin,Y) <= Compound-causes-Side-Effect(Tretinoin,Y)
# 37 37 1.000000 Compound-causes-Side-Effect(X,Rash) <= Compound-causes-Side-Effect(X,Anger)
# 453 453 1.000000 Compound-causes-Side-Effect(Alitretinoin,Y) <= Compound-causes-Side-Effect(Isotretinoin,Y)
# 461 461 1.000000 Compound-causes-Side-Effect(X,Musculoskeletal discomfort) <= Compound-causes-Side-Effect(X,Myalgia)
# 54 54 1.000000 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Duodenal ulcer)
# 50 50 1.000000 Gene-participates-Biological_Process(X,nucleobase-containing small molecule metabolic process) <= Gene-participates-Biological_Process(X,ribonucleoSide_triphosphate biosynthetic process)
# 23 23 1.000000 Gene-participates-Biological_Process(X,purine ribonucleoSide_triphosphate biosynthetic process) <= Gene-participates-Biological_Process(X,energy coupled proton transport, down electrochemical gradient)
# 106 106 1.000000 Compound-causes-Side-Effect(X,Hypoaesthesia) <= Compound-causes-Side-Effect(X,Numbness)
# 71 71 1.000000 Compound-causes-Side-Effect(Liotrix,Y) <= Compound-causes-Side-Effect(Dextrothyroxine,Y)
# 20 20 1.000000 Compound-causes-Side-Effect(X,Somnolence) <= Compound-causes-Side-Effect(X,Hysteria)
# 414 414 1.000000 Compound-causes-Side-Effect(X,Discomfort) <= Compound-causes-Side-Effect(X,Ill-defined disorder)
# 45 45 1.000000 Gene-participates-Biological_Process(X,nucleoSide_phosphate biosynthetic process) <= Gene-participates-Biological_Process(X,purine nucleoSide_triphosphate biosynthetic process)
# 37 37 1.000000 Gene-participates-Biological_Process(X,nucleoSide_phosphate metabolic process) <= Gene-participates-Biological_Process(X,NADH metabolic process)
# 37 37 1.000000 Gene-participates-Biological_Process(X,purine nucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,ribonucleoSide_bisphosphate metabolic process)
# 90 90 1.000000 Compound-causes-Side-Effect(Potassium Iodide,Y) <= Compound-causes-Side-Effect(Gallamine Triethiodide,Y)
# 82 82 1.000000 Compound-causes-Side-Effect(X,Pancytopenia) <= Compound-causes-Side-Effect(X,Bone marrow depression)
# 96 96 1.000000 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Tubulointerstitial nephritis)
# 50 50 1.000000 Gene-participates-Biological_Process(X,nucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,ribonucleoSide_triphosphate biosynthetic process)
# 162 162 1.000000 Gene-participates-Biological_Process(X,purine ribonucleoSide_monophosphate metabolic process) <= Gene-participates-Biological_Process(X,ATP metabolic process)
# 21 21 1.000000 Gene-participates-Biological_Process(X,nucleoSide_biosynthetic process) <= Gene-participates-Biological_Process(X,pyrimidine ribonucleoSide_biosynthetic process)
# 199 199 1.000000 Gene-participates-Biological_Process(X,purine nucleoSide_monophosphate metabolic process) <= Gene-participates-Biological_Process(X,purine ribonucleoSide_monophosphate metabolic process)
# 21 21 1.000000 Gene-participates-Biological_Process(X,ribonucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,pyrimidine ribonucleoSide_biosynthetic process)
# 212 212 1.000000 Compound-causes-Side-Effect(Phenytoin,Y) <= Compound-causes-Side-Effect(Fosphenytoin,Y)
# 60 60 1.000000 Gene-participates-Biological_Process(X,ribonucleoSide_triphosphate metabolic process) <= Gene-participates-Biological_Process(X,ATP synthesis coupled electron transport)
# 87 87 1.000000 Gene-participates-Biological_Process(X,glycosyl compound biosynthetic process) <= Gene-participates-Biological_Process(X,purine nucleoSide_biosynthetic process)
# 31 31 1.000000 Compound-causes-Side-Effect(X,Asthenia) <= Compound-causes-Side-Effect(X,Polydipsia)
# 182 182 1.000000 Gene-participates-Biological_Process(X,organophosphate metabolic process) <= Gene-participates-Biological_Process(X,ribonucleoSide_triphosphate metabolic process)
# 44 44 1.000000 Gene-participates-Biological_Process(X,glycosyl compound biosynthetic process) <= Gene-participates-Biological_Process(X,purine ribonucleoSide_triphosphate biosynthetic process)
# 31 31 1.000000 Gene-participates-Biological_Process(X,pyrimidine-containing compound metabolic process) <= Gene-participates-Biological_Process(X,pyrimidine nucleoSide_biosynthetic process)
# 116 116 1.000000 Gene-participates-Biological_Process(X,nucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,nucleoSide_biosynthetic process)
# 37 37 1.000000 Gene-participates-Biological_Process(X,ribose phosphate metabolic process) <= Gene-participates-Biological_Process(X,nucleoSide_bisphosphate metabolic process)
# 116 116 1.000000 Gene-participates-Biological_Process(X,glycosyl compound metabolic process) <= Gene-participates-Biological_Process(X,nucleoSide_biosynthetic process)
# 26 26 1.000000 Gene-participates-Biological_Process(X,membrane lipid metabolic process) <= Gene-participates-Biological_Process(X,ganglioSide_metabolic process)
# 47 47 1.000000 Gene-participates-Biological_Process(X,nucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,ADP metabolic process)
# 87 87 1.000000 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Interstitial lung disease)
# 31 31 1.000000 Compound-causes-Side-Effect(X,Constipation) <= Compound-causes-Side-Effect(X,Skin mass)
# 108 108 1.000000 Compound-causes-Side-Effect(Gadoxetate,Y) <= Compound-causes-Side-Effect(Sodium lauryl sulfate,Y)
# 59 59 1.000000 Gene-participates-Biological_Process(X,purine nucleoSide_monophosphate metabolic process) <= Gene-participates-Biological_Process(X,mitochondrial ATP synthesis coupled electron transport)
# 96 96 1.000000 Gene-participates-Cellular_Component(X,cytoplasmic Side_of plasma membrane) <= Gene-participates-Cellular_Component(X,extrinsic component of cytoplasmic Side_of plasma membrane)
# 74 74 1.000000 Compound-causes-Side-Effect(Conjugated Estrogens,Y) <= Compound-causes-Side-Effect(Estrone,Y)
# 46 46 1.000000 Compound-causes-Side-Effect(X,Rash) <= Compound-causes-Side-Effect(X,Prostatic disorder)
# 39 39 1.000000 Gene-participates-Biological_Process(X,purine nucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,ATP generation from ADP)
# 69 69 1.000000 Compound-causes-Side-Effect(X,Dizziness) <= Compound-causes-Side-Effect(X,Completed suicide)
# 301 301 1.000000 Gene-participates-Biological_Process(X,glycosyl compound metabolic process) <= Gene-participates-Biological_Process(X,ribonucleoSide_metabolic process)
# 23 23 1.000000 Gene-participates-Biological_Process(X,purine ribonucleoSide_monophosphate biosynthetic process) <= Gene-participates-Biological_Process(X,energy coupled proton transport, down electrochemical gradient)
# 38 38 1.000000 Gene-participates-Biological_Process(X,purine ribonucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,guanosine-containing compound metabolic process)
# 25 25 1.000000 Compound-causes-Side-Effect(X,Constipation) <= Compound-causes-Side-Effect(X,Skin lesion)
# 22 22 1.000000 Compound-causes-Side-Effect(X,Headache) <= Compound-causes-Side-Effect(X,Mental status changes)
# 140 140 1.000000 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Cystitis)
# 432 432 1.000000 Compound-causes-Side-Effect(X,Dizziness) <= Compound-causes-Side-Effect(X,Syncope)
# 453 453 1.000000 Compound-causes-Side-Effect(Tretinoin,Y) <= Compound-causes-Side-Effect(Isotretinoin,Y)
# 182 182 1.000000 Gene-participates-Biological_Process(X,ribose phosphate metabolic process) <= Gene-participates-Biological_Process(X,ribonucleoSide_triphosphate metabolic process)
# 54 54 1.000000 Compound-causes-Side-Effect(X,Interstitial lung disease) <= Compound-causes-Side-Effect(X,Interstitial pneumonia)
# 490 490 1.000000 Compound-causes-Side-Effect(Ofloxacin,Y) <= Compound-causes-Side-Effect(Levofloxacin,Y)
# 108 108 1.000000 Compound-causes-Side-Effect(Liotrix,Y) <= Compound-causes-Side-Effect(Sodium lauryl sulfate,Y)
# 490 490 1.000000 Compound-causes-Side-Effect(Levofloxacin,Y) <= Compound-causes-Side-Effect(Ofloxacin,Y)
# 465 465 1.000000 Compound-causes-Side-Effect(X,Skin disorder) <= Compound-causes-Side-Effect(X,Unspecified disorder of skin and subcutaneous tissue)
# 24 24 1.000000 Gene-participates-Biological_Process(X,nucleoSide_metabolic process) <= Gene-participates-Pathway(X,Pyrimidine metabolism)
# 162 162 1.000000 Gene-participates-Biological_Process(X,ribonucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,ATP metabolic process)
# 40 40 1.000000 Compound-causes-Side-Effect(X,Dermatitis) <= Compound-causes-Side-Effect(X,Hypertrichosis)
# 180 180 1.000000 Gene-participates-Biological_Process(X,nucleoSide_phosphate biosynthetic process) <= Gene-participates-Biological_Process(X,nucleotide biosynthetic process)
# 35 35 1.000000 Gene-participates-Biological_Process(X,purine ribonucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,ATP biosynthetic process)
# 30 30 1.000000 Compound-causes-Side-Effect(X,Hypertension) <= Compound-causes-Side-Effect(X,Breast neoplasm)
# 516 516 1.000000 Compound-causes-Side-Effect(X,Decreased appetite) <= Compound-causes-Side-Effect(X,Anorexia)
# 111 111 1.000000 Compound-causes-Side-Effect(Gadofosveset trisodium,Y) <= Compound-causes-Side-Effect(Sodium stibogluconate,Y)
# 55 55 1.000000 Compound-causes-Side-Effect(X,Agitation) <= Compound-causes-Side-Effect(X,Excitement)
# 21 21 1.000000 Compound-causes-Side-Effect(X,Vomiting) <= Compound-causes-Side-Effect(X,Gastrointestinal discomfort)
# 21 21 1.000000 Compound-causes-Side-Effect(X,Musculoskeletal discomfort) <= Compound-causes-Side-Effect(X,Hyperlactacidaemia)
# 88 88 1.000000 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Nystagmus)
# 127 127 1.000000 Compound-causes-Side-Effect(X,Headache) <= Compound-causes-Side-Effect(X,Bone pain)
# 453 453 1.000000 Compound-causes-Side-Effect(Alitretinoin,Y) <= Compound-causes-Side-Effect(Tretinoin,Y)
# 27 27 1.000000 Gene-participates-Biological_Process(X,purine nucleoSide_monophosphate metabolic process) <= Gene-participates-Biological_Process(X,canonical glycolysis)
# 27 27 1.000000 Compound-causes-Side-Effect(X,Vomiting) <= Compound-causes-Side-Effect(X,Skin nodule)
# 277 277 1.000000 Compound-causes-Side-Effect(X,Somnolence) <= Compound-causes-Side-Effect(X,Drowsiness)
# 108 108 1.000000 Compound-causes-Side-Effect(Gadofosveset trisodium,Y) <= Compound-causes-Side-Effect(Sodium lauryl sulfate,Y)
# 20 20 1.000000 Compound-causes-Side-Effect(X,Insomnia) <= Compound-causes-Side-Effect(X,Obesity)
# 20 20 1.000000 Compound-causes-Side-Effect(X,Headache) <= Compound-causes-Side-Effect(X,Basedow's disease)
# 73 73 1.000000 Compound-causes-Side-Effect(X,Rash) <= Compound-causes-Side-Effect(X,Eruption)
# 26 26 1.000000 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Red blood cell sedimentation rate increased)
# 34 34 1.000000 Gene-participates-Biological_Process(X,nucleoSide_phosphate metabolic process) <= Gene-participates-Biological_Process(X,cAMP metabolic process)
# 110 110 1.000000 Compound-causes-Side-Effect(Adenosine,Y) <= Compound-causes-Side-Effect(Vidarabine,Y)
# 170 170 1.000000 Compound-causes-Side-Effect(X,Photosensitivity reaction) <= Compound-causes-Side-Effect(X,Photosensitivity)
# 45 45 1.000000 Gene-participates-Biological_Process(X,nucleoSide_phosphate metabolic process) <= Gene-participates-Biological_Process(X,purine nucleoSide_triphosphate biosynthetic process)
# 20 20 1.000000 Compound-causes-Side-Effect(X,Nausea) <= Pharmacologic_Class-includes-Compound(Cytochrome P450 3A4 Inhibitors,X)
# 275 275 1.000000 Gene-participates-Biological_Process(X,nucleobase-containing small molecule metabolic process) <= Gene-participates-Biological_Process(X,purine nucleoSide_metabolic process)
# 68 68 1.000000 Compound-causes-Side-Effect(X,Vomiting) <= Compound-causes-Side-Effect(X,Hypophosphataemia)
# 65 65 1.000000 Compound-causes-Side-Effect(X,Body temperature decreased) <= Compound-causes-Side-Effect(X,Hypothermia)
# 332 332 1.000000 Compound-causes-Side-Effect(Methylphenidate,Y) <= Compound-causes-Side-Effect(Dexmethylphenidate,Y)
# 176 176 1.000000 Gene-participates-Biological_Process(X,nucleobase-containing small molecule metabolic process) <= Gene-participates-Biological_Process(X,purine ribonucleoSide_triphosphate metabolic process)
# 28 28 1.000000 Compound-causes-Side-Effect(X,Fatigue) <= Compound-causes-Side-Effect(X,Sciatica)
# 450 450 1.000000 Gene-participates-Biological_Process(X,nucleobase-containing small molecule metabolic process) <= Gene-participates-Biological_Process(X,nucleoSide_phosphate metabolic process)
# 181 181 1.000000 Compound-causes-Side-Effect(Conjugated Estrogens,Y) <= Compound-causes-Side-Effect(Estropipate,Y)
# 249 249 1.000000 Compound-causes-Side-Effect(Betamethasone,Y) <= Compound-causes-Side-Effect(Dexamethasone,Y)
# 302 302 1.000000 Compound-causes-Side-Effect(Omeprazole,Y) <= Compound-causes-Side-Effect(Esomeprazole,Y)
# 277 277 1.000000 Compound-causes-Side-Effect(X,Infestation NOS) <= Compound-causes-Side-Effect(X,Infestation)
# 45 45 1.000000 Compound-causes-Side-Effect(Hydromorphone,Y) <= Compound-causes-Side-Effect(Dihydrocodeine,Y)
# 65 65 1.000000 Compound-causes-Side-Effect(X,Hypothermia) <= Compound-causes-Side-Effect(X,Body temperature decreased)
# 259 259 1.000000 Compound-causes-Side-Effect(Zopiclone,Y) <= Compound-causes-Side-Effect(Eszopiclone,Y)
# 56 56 1.000000 Compound-causes-Side-Effect(Pseudoephedrine,Y) <= Compound-causes-Side-Effect(Ephedrine,Y)
# 585 584 0.998291 Compound-causes-Side-Effect(X,Asthenia) <= Compound-causes-Side-Effect(X,Fatigue)
# 332 331 0.996988 Gene-participates-Biological_Process(X,nucleoSide_phosphate metabolic process) <= Gene-participates-Biological_Process(X,ribose phosphate metabolic process)
# 461 459 0.995662 Compound-causes-Side-Effect(X,Musculoskeletal discomfort) <= Compound-causes-Side-Effect(X,Arthralgia)
# 211 210 0.995261 Gene-participates-Biological_Process(X,nucleotide metabolic process) <= Gene-participates-Biological_Process(X,ribonucleoSide_monophosphate metabolic process)
# 199 198 0.994975 Gene-participates-Biological_Process(X,purine nucleotide metabolic process) <= Gene-participates-Biological_Process(X,purine ribonucleoSide_monophosphate metabolic process)
# 188 187 0.994681 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Thirst)
# 176 175 0.994318 Gene-participates-Biological_Process(X,purine nucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,purine ribonucleoSide_triphosphate metabolic process)
# 176 175 0.994318 Gene-participates-Biological_Process(X,nucleoSide_metabolic process) <= Gene-participates-Biological_Process(X,purine ribonucleoSide_triphosphate metabolic process)
# 481 478 0.993763 Compound-causes-Side-Effect(X,Feeling abnormal) <= Compound-causes-Side-Effect(X,Confusional state)
# 317 315 0.993691 Compound-causes-Side-Effect(X,Haemoglobin) <= Compound-causes-Side-Effect(X,Haemorrhage)
# 144 143 0.993056 Compound-causes-Side-Effect(X,Rash) <= Compound-causes-Side-Effect(X,Vaginal infection)
# 286 284 0.993007 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Stomatitis)
# 282 280 0.992908 Compound-causes-Side-Effect(X,Myocardial infarction) <= Compound-causes-Side-Effect(X,Acute coronary syndrome)
# 134 133 0.992537 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Pulmonary embolism)
# 134 133 0.992537 Compound-causes-Side-Effect(X,Rash) <= Compound-causes-Side-Effect(X,Vaginal inflammation)
# 131 130 0.992366 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Blood uric acid increased)
# 625 620 0.992000 Compound-causes-Side-Effect(X,Abdominal pain) <= Compound-causes-Side-Effect(X,Gastrointestinal pain)
# 113 112 0.991150 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Breast pain)
# 224 222 0.991071 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Abdominal pain upper)
# 223 221 0.991031 Gene-participates-Biological_Process(X,nucleotide metabolic process) <= Gene-participates-Biological_Process(X,nucleoSide_monophosphate metabolic process)
# 111 110 0.990991 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Delirium)
# 325 322 0.990769 Compound-causes-Side-Effect(X,Urinary tract disorder) <= Compound-causes-Side-Effect(X,Urethral disorder)
# 429 425 0.990676 Compound-causes-Side-Effect(X,Feeling abnormal) <= Compound-causes-Side-Effect(X,Malaise)
# 105 104 0.990476 Compound-causes-Side-Effect(Nortriptyline,Y) <= Compound-causes-Side-Effect(Protriptyline,Y)
# 209 207 0.990431 Compound-causes-Side-Effect(X,Dermatitis) <= Compound-causes-Side-Effect(X,Face oedema)
# 104 103 0.990385 Compound-causes-Side-Effect(Estradiol,Y) <= Compound-causes-Side-Effect(Estradiol valerate/Dienogest,Y)
# 204 202 0.990196 Compound-causes-Side-Effect(X,Dizziness) <= Compound-causes-Side-Effect(X,Migraine)
# 195 193 0.989744 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Lethargy)
# 95 94 0.989474 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Scotoma)
# 283 280 0.989399 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Renal failure)
# 265 262 0.988679 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Pollakiuria)
# 88 87 0.988636 Compound-causes-Side-Effect(X,Rash) <= Compound-causes-Side-Effect(X,Metrorrhagia)
# 87 86 0.988506 Compound-causes-Side-Effect(X,Vomiting) <= Compound-causes-Side-Effect(X,Interstitial lung disease)
# 83 82 0.987952 Compound-causes-Side-Effect(X,Diarrhoea) <= Compound-causes-Side-Effect(X,Menstrual disorder)
# 83 82 0.987952 Compound-causes-Side-Effect(X,Asthenia) <= Compound-causes-Side-Effect(X,Paranoia)
# 158 156 0.987342 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Hypertonia)
# 78 77 0.987179 Compound-causes-Side-Effect(X,Vomiting) <= Compound-causes-Side-Effect(X,Aphasia)
# 228 225 0.986842 Compound-causes-Side-Effect(X,Vomiting) <= Compound-causes-Side-Effect(X,Toxic epidermal necrolysis)
# 149 147 0.986577 Compound-causes-Side-Effect(X,Nausea) <= Compound-causes-Side-Effect(X,Cramps of lower extremities)
# 73 72 0.986301 Compound-causes-Side-Effect(Citalopram,Y) <= Compound-causes-Side-Effect(Desloratadine,Y)

# %%
# now display the strongest cyclical dependencies
# we have to load the data again because we performed the entity/relation_strings substitutions
# for more redable outputs but the rules appear in raw form
opts.set("loader.load_u_d_rules", False)
opts.set("loader.load_u_c_rules", False)
opts.set("loader.load_u_xxd_rules", False)
opts.set("loader.load_u_xxc_rules", False)
opts.set("loader.load_zero_rules", False)
opts.set("loader.load_b_rules", True)

loader_1 = Loader(opts.get("loader"))
loader_1.load_data(train)
loader_1.load_rules(rules=rules_all)
loader_1.replace_rel_strings(relation_names)
loader_1.replace_ent_strings(entity_names)

rules = loader_1.get_rules()
rules = [line.split("\t") for line in rules]
rules.sort(key=lambda in_list: in_list[2], reverse=True)
num_rules  = 500
for i in range(num_rules):
    print(rules[i][0], rules[i][1],rules[i][2], rules[i][3])
# Out:
# Setting option load_zero_rules to: False
# Setting option z_weight to: 0.1
# Setting option z_num_unseen to: 5
# Setting option z_min_support to: -1
# Setting option z_min_preds to: -1
# Setting option z_min_conf to: 0.0001
# Setting option load_u_c_rules to: False
# Setting option c_num_unseen to: 5
# Setting option c_min_support to: 20
# Setting option c_min_preds to: -1
# Setting option c_min_conf to: 0.0001
# Setting option c_max_length to: -1
# Setting option load_b_rules to: True
# Setting option b_max_branching_factor to: -1
# Setting option b_num_unseen to: 5
# Setting option b_min_support to: -1
# Setting option b_min_preds to: -1
# Setting option b_min_conf to: 0.0001
# Setting option b_max_length to: -1
# Setting option load_u_d_rules to: False
# Setting option d_weight to: 0.01
# Setting option d_max_branching_factor to: -1
# Setting option d_num_unseen to: 5
# Setting option d_min_support to: -1
# Setting option d_min_preds to: -1
# Setting option d_min_conf to: 0.0001
# Setting option d_max_length to: -1
# Setting option load_u_xxc_rules to: False
# Setting option xxc_num_unseen to: 5
# Setting option xxc_min_support to: -1
# Setting option xxc_min_preds to: -1
# Setting option xxc_min_conf to: 0.0001
# Setting option load_u_xxd_rules to: False
# Setting option xxd_num_unseen to: 5
# Setting option xxd_min_support to: -1
# Setting option xxd_min_preds to: -1
# Setting option xxd_min_conf to: 0.0001
# Loading triples...
# Loaded triples.
# Loading rules from /home/patrick/Desktop/PyClause/local/paper-demonstration/anyburl-rules-all.txt
# ...parsed 1000000 rules
# Loaded 2223 rules.
# 2000 1699 0.849500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,Y)
# 2000 1483 0.741500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Compound-downregulates-Gene(B,A), Compound-upregulates-Gene(B,Y)
# 2000 1474 0.737000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 1467 0.733500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 1464 0.732000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 1459 0.729500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 1458 0.729000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 1455 0.727500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 1451 0.725500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Compound-downregulates-Gene(B,A), Compound-upregulates-Gene(B,Y)
# 2000 1449 0.724500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Compound-upregulates-Gene(B,A), Compound-upregulates-Gene(B,Y)
# 2000 1448 0.724000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Compound-downregulates-Gene(B,A), Compound-downregulates-Gene(B,Y)
# 2000 1444 0.722000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Compound-downregulates-Gene(B,A), Compound-downregulates-Gene(B,Y)
# 2000 1437 0.718500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 1434 0.717000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 1432 0.716000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Compound-upregulates-Gene(B,A), Compound-downregulates-Gene(B,Y)
# 2000 1423 0.711500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Compound-upregulates-Gene(B,A), Compound-downregulates-Gene(B,Y)
# 2000 1422 0.711000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,Y)
# 2000 1418 0.709000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 1416 0.708000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 1414 0.707000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 1414 0.707000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 1412 0.706000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,Y)
# 2000 1399 0.699500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 1399 0.699500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 1385 0.692500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(Y,A)
# 2000 1381 0.690500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 1360 0.680000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(Y,A)
# 2000 1356 0.678000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 1356 0.678000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 1355 0.677500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 1349 0.674500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 1347 0.673500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 1346 0.673000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(Y,A)
# 2000 1339 0.669500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 1338 0.669000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 1335 0.667500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 1334 0.667000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 1330 0.665000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 1322 0.661000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 1321 0.660500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 1317 0.658500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(Y,A)
# 2000 1314 0.657000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 1314 0.657000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 1314 0.657000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 1312 0.656000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 1311 0.655500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 1311 0.655500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 1311 0.655500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 1309 0.654500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 1301 0.650500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 1300 0.650000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 1300 0.650000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 1297 0.648500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 1286 0.643000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 1280 0.640000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 1268 0.634000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 1267 0.633500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 1248 0.624000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 1246 0.623000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 1242 0.621000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 1234 0.617000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 1233 0.616500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 1233 0.616500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-downregulates-Gene(B,Y)
# 2000 1229 0.614500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 1228 0.614000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 1228 0.614000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 1226 0.613000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 1226 0.613000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-participates-Pathway(A,B), Gene-participates-Pathway(Y,B)
# 2000 1226 0.613000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-downregulates-Gene(B,A), Disease-downregulates-Gene(B,Y)
# 2000 1224 0.612000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 1224 0.612000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 1224 0.612000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-associates-Gene(B,A), Disease-downregulates-Gene(B,Y)
# 2000 1221 0.610500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-associates-Gene(B,A), Disease-upregulates-Gene(B,Y)
# 2000 1220 0.610000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-downregulates-Gene(B,A), Disease-downregulates-Gene(B,Y)
# 2000 1220 0.610000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-downregulates-Gene(B,Y)
# 2000 1218 0.609000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 1217 0.608500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-upregulates-Gene(B,Y)
# 2000 1217 0.608500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 1213 0.606500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 1210 0.605000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,Y)
# 2000 1207 0.603500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 1207 0.603500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 1198 0.599000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-associates-Gene(B,A), Disease-downregulates-Gene(B,Y)
# 2000 1195 0.597500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-participates-Cellular_Component(A,B), Gene-participates-Cellular_Component(Y,B)
# 2000 1190 0.595000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 1187 0.593500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 1183 0.591500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-downregulates-Gene(B,A), Disease-upregulates-Gene(B,Y)
# 2000 1180 0.590000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,Y)
# 2000 1176 0.588000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-downregulates-Gene(B,A), Disease-upregulates-Gene(B,Y)
# 2000 1175 0.587500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-upregulates-Gene(B,Y)
# 2000 1173 0.586500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 1170 0.585000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-associates-Gene(B,A), Disease-upregulates-Gene(B,Y)
# 2000 1158 0.579000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 1157 0.578500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 1155 0.577500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-participates-Cellular_Component(A,B), Gene-participates-Cellular_Component(Y,B)
# 2000 1154 0.577000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 1149 0.574500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-associates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 1147 0.573500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-participates-Biological_Process(A,B), Gene-participates-Biological_Process(Y,B)
# 2000 1147 0.573500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-participates-Biological_Process(A,B), Gene-participates-Biological_Process(Y,B)
# 2000 1131 0.565500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-participates-Pathway(A,B), Gene-participates-Pathway(Y,B)
# 2000 1128 0.564000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-associates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 1128 0.564000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-downregulates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 1125 0.562500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 1119 0.559500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 1104 0.552000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 1103 0.551500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-participates-Molecular_Function(A,B), Gene-participates-Molecular_Function(Y,B)
# 2000 1099 0.549500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-participates-Molecular_Function(A,B), Gene-participates-Molecular_Function(Y,B)
# 2000 1098 0.549000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 1082 0.541000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 1082 0.541000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 1070 0.535000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 1067 0.533500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 1056 0.528000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 1052 0.526000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-covaries-Gene(Y,B)
# 2000 1051 0.525500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 1046 0.523000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Compound-downregulates-Gene(B,A), Compound-binds-Gene(B,Y)
# 2000 1043 0.521500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 1041 0.520500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-covaries-Gene(Y,B)
# 2000 1040 0.520000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,Y)
# 1947 1009 0.518233 Compound-resembles-Compound(X,Y) <= Compound-resembles-Compound(X,A), Compound-resembles-Compound(A,Y)
# 2000 1032 0.516000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 1029 0.514500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Compound-binds-Gene(B,A), Compound-binds-Gene(B,Y)
# 2000 1027 0.513500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 1025 0.512500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,Y)
# 2000 1024 0.512000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Compound-binds-Gene(B,A), Compound-binds-Gene(B,Y)
# 2000 1023 0.511500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 1014 0.507000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 1013 0.506500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 1012 0.506000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,Y)
# 2000 1011 0.505500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(Y,A)
# 2000 1004 0.502000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-covaries-Gene(Y,B)
# 2000 990 0.495000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 971 0.485500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(Y,A)
# 2000 962 0.481000 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-covaries-Gene(Y,B)
# 2000 957 0.478500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 954 0.477000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 943 0.471500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-covaries-Gene(Y,B)
# 2000 941 0.470500 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-covaries-Gene(Y,B)
# 2000 932 0.466000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Compound-downregulates-Gene(B,A), Compound-downregulates-Gene(B,Y)
# 2000 929 0.464500 Anatomy-expresses-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 914 0.457000 Anatomy-expresses-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 913 0.456500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Compound-downregulates-Gene(B,A), Compound-upregulates-Gene(B,Y)
# 2000 908 0.454000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Compound-upregulates-Gene(B,A), Compound-downregulates-Gene(B,Y)
# 2000 900 0.450000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-covaries-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 888 0.444000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-interacts-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 882 0.441000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-regulates-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 879 0.439500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Compound-upregulates-Gene(B,A), Compound-upregulates-Gene(B,Y)
# 2000 876 0.438000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-covaries-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 863 0.431500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-covaries-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 848 0.424000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-covaries-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 844 0.422000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-regulates-Gene(Y,A)
# 2000 827 0.413500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-regulates-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 822 0.411000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-interacts-Gene(Y,A)
# 2000 820 0.410000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-interacts-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 819 0.409500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-regulates-Gene(A,Y)
# 2000 818 0.409000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-interacts-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 809 0.404500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-regulates-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 794 0.397000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-covaries-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 788 0.394000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-covaries-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 787 0.393500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-regulates-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 784 0.392000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-regulates-Gene(A,B), Gene-regulates-Gene(Y,B)
# 1584 617 0.389520 Compound-resembles-Compound(X,Y) <= Compound-resembles-Compound(X,A), Compound-resembles-Compound(A,B), Compound-resembles-Compound(B,Y)
# 2000 777 0.388500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-regulates-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 774 0.387000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-interacts-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 761 0.380500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-regulates-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 758 0.379000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-interacts-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 756 0.378000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 755 0.377500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-interacts-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 752 0.376000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Compound-binds-Gene(B,A), Compound-downregulates-Gene(B,Y)
# 2000 747 0.373500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Compound-binds-Gene(B,A), Compound-upregulates-Gene(B,Y)
# 2000 746 0.373000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 744 0.372000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 744 0.372000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Disease-downregulates-Gene(B,A), Disease-downregulates-Gene(B,Y)
# 2000 735 0.367500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-upregulates-Gene(B,Y)
# 2000 735 0.367500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 734 0.367000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 731 0.365500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-interacts-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 730 0.365000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 728 0.364000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 725 0.362500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-covaries-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 721 0.360500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-downregulates-Gene(B,Y)
# 2000 720 0.360000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Disease-downregulates-Gene(B,A), Disease-associates-Gene(B,Y)
# 517 186 0.359768 Disease-resembles-Disease(X,Y) <= Disease-resembles-Disease(X,A), Disease-resembles-Disease(A,Y)
# 2000 717 0.358500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 711 0.355500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-regulates-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 710 0.355000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-covaries-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 705 0.352500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Disease-downregulates-Gene(B,A), Disease-upregulates-Gene(B,Y)
# 2000 704 0.352000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-interacts-Gene(A,Y)
# 2000 699 0.349500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 693 0.346500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Compound-downregulates-Gene(B,A), Compound-binds-Gene(B,Y)
# 2000 691 0.345500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-covaries-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 689 0.344500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-participates-Pathway(A,B), Gene-participates-Pathway(Y,B)
# 2000 688 0.344000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-participates-Cellular_Component(A,B), Gene-participates-Cellular_Component(Y,B)
# 2000 675 0.337500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-participates-Biological_Process(A,B), Gene-participates-Biological_Process(Y,B)
# 2000 672 0.336000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 668 0.334000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-covaries-Gene(B,A), Gene-covaries-Gene(Y,B)
# 2000 667 0.333500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-participates-Molecular_Function(A,B), Gene-participates-Molecular_Function(Y,B)
# 2000 662 0.331000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Compound-upregulates-Gene(B,A), Compound-binds-Gene(B,Y)
# 2000 661 0.330500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-covaries-Gene(A,B), Gene-covaries-Gene(Y,B)
# 1793 587 0.327384 Disease-localizes-Anatomy(X,Y) <= Disease-resembles-Disease(A,X), Disease-localizes-Anatomy(A,Y)
# 2000 654 0.327000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Disease-associates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 645 0.322500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-covaries-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 642 0.321000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-covaries-Gene(A,Y)
# 2000 639 0.319500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-interacts-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 638 0.319000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-interacts-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 637 0.318500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Disease-associates-Gene(B,A), Disease-downregulates-Gene(B,Y)
# 1878 596 0.317359 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-regulates-Gene(B,A), Gene-covaries-Gene(Y,B)
# 2000 634 0.317000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-regulates-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 633 0.316500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Compound-binds-Gene(B,A), Compound-binds-Gene(B,Y)
# 2000 629 0.314500 Compound-resembles-Compound(X,Y) <= Compound-resembles-Compound(X,A), Compound-resembles-Compound(B,A), Compound-resembles-Compound(B,Y)
# 2000 623 0.311500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-regulates-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 623 0.311500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-covaries-Gene(Y,A)
# 2000 611 0.305500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Disease-associates-Gene(B,A), Disease-upregulates-Gene(B,Y)
# 2000 604 0.302000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-interacts-Gene(B,A), Gene-covaries-Gene(Y,B)
# 1959 586 0.299132 Disease-presents-Symptom(X,Y) <= Disease-resembles-Disease(X,A), Disease-presents-Symptom(A,Y)
# 2000 592 0.296000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-regulates-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 587 0.293500 Disease-localizes-Anatomy(X,Y) <= Disease-resembles-Disease(X,A), Disease-localizes-Anatomy(A,Y)
# 1953 564 0.288786 Disease-presents-Symptom(X,Y) <= Disease-resembles-Disease(A,X), Disease-presents-Symptom(A,Y)
# 2000 576 0.288000 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-interacts-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 574 0.287000 Compound-resembles-Compound(X,Y) <= Compound-resembles-Compound(X,A), Compound-resembles-Compound(Y,A)
# 2000 568 0.284000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 559 0.279500 Compound-resembles-Compound(X,Y) <= Compound-resembles-Compound(A,X), Compound-resembles-Compound(A,Y)
# 2000 556 0.278000 Compound-binds-Gene(X,Y) <= Pharmacologic_Class-includes-Compound(A,X), Pharmacologic_Class-includes-Compound(A,B), Compound-binds-Gene(B,Y)
# 2000 551 0.275500 Anatomy-expresses-Gene(X,Y) <= Anatomy-expresses-Gene(X,A), Gene-interacts-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 538 0.269000 Compound-resembles-Compound(X,Y) <= Compound-resembles-Compound(X,A), Compound-resembles-Compound(A,B), Compound-resembles-Compound(Y,B)
# 2000 534 0.267000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 546 145 0.265568 Pharmacologic_Class-includes-Compound(X,Y) <= Pharmacologic_Class-includes-Compound(X,A), Compound-resembles-Compound(A,Y)
# 2000 530 0.265000 Compound-resembles-Compound(X,Y) <= Compound-resembles-Compound(A,X), Compound-resembles-Compound(A,B), Compound-resembles-Compound(B,Y)
# 681 179 0.262849 Pharmacologic_Class-includes-Compound(X,Y) <= Pharmacologic_Class-includes-Compound(X,A), Pharmacologic_Class-includes-Compound(B,A), Pharmacologic_Class-includes-Compound(B,Y)
# 2000 525 0.262500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 1567 395 0.252074 Compound-binds-Gene(X,Y) <= Compound-resembles-Compound(A,X), Compound-binds-Gene(A,Y)
# 2000 501 0.250500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 497 0.248500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 490 0.245000 Gene-participates-Molecular_Function(X,Y) <= Gene-participates-Molecular_Function(X,A), Gene-participates-Molecular_Function(B,A), Gene-participates-Molecular_Function(B,Y)
# 2000 489 0.244500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 482 0.241000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(Y,A)
# 2000 480 0.240000 Compound-causes-Side-Effect(X,Y) <= Pharmacologic_Class-includes-Compound(A,X), Pharmacologic_Class-includes-Compound(A,B), Compound-causes-Side-Effect(B,Y)
# 2000 477 0.238500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Compound-upregulates-Gene(B,A), Compound-upregulates-Gene(B,Y)
# 2000 476 0.238000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 700 166 0.237143 Pharmacologic_Class-includes-Compound(X,Y) <= Pharmacologic_Class-includes-Compound(X,A), Compound-resembles-Compound(Y,A)
# 2000 474 0.237000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(Y,A)
# 2000 471 0.235500 Compound-binds-Gene(X,Y) <= Compound-resembles-Compound(X,A), Compound-binds-Gene(A,Y)
# 2000 465 0.232500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 462 0.231000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 462 0.231000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 462 0.231000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 457 0.228500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 454 0.227000 Compound-resembles-Compound(X,Y) <= Compound-resembles-Compound(X,A), Pharmacologic_Class-includes-Compound(B,A), Pharmacologic_Class-includes-Compound(B,Y)
# 2000 452 0.226000 Compound-resembles-Compound(X,Y) <= Pharmacologic_Class-includes-Compound(A,X), Pharmacologic_Class-includes-Compound(A,B), Compound-resembles-Compound(B,Y)
# 2000 451 0.225500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 450 0.225000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 448 0.224000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 447 0.223500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 447 0.223500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 447 0.223500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-participates-Cellular_Component(A,B), Gene-participates-Cellular_Component(Y,B)
# 2000 446 0.223000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Compound-downregulates-Gene(B,A), Compound-upregulates-Gene(B,Y)
# 2000 445 0.222500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 441 0.220500 Compound-causes-Side-Effect(X,Y) <= Compound-palliates-Disease(X,A), Compound-palliates-Disease(B,A), Compound-causes-Side-Effect(B,Y)
# 2000 440 0.220000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 439 0.219500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Compound-upregulates-Gene(B,A), Compound-upregulates-Gene(B,Y)
# 2000 439 0.219500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-participates-Biological_Process(A,B), Gene-participates-Biological_Process(Y,B)
# 2000 438 0.219000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 437 0.218500 Gene-participates-Pathway(X,Y) <= Gene-participates-Pathway(X,A), Gene-participates-Pathway(B,A), Gene-participates-Pathway(B,Y)
# 2000 435 0.217500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Compound-downregulates-Gene(B,A), Compound-downregulates-Gene(B,Y)
# 2000 435 0.217500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 434 0.217000 Gene-participates-Molecular_Function(X,Y) <= Compound-binds-Gene(A,X), Compound-binds-Gene(A,B), Gene-participates-Molecular_Function(B,Y)
# 2000 434 0.217000 Gene-participates-Cellular_Component(X,Y) <= Gene-participates-Cellular_Component(X,A), Gene-participates-Cellular_Component(B,A), Gene-participates-Cellular_Component(B,Y)
# 2000 434 0.217000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-participates-Pathway(A,B), Gene-participates-Pathway(Y,B)
# 2000 433 0.216500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 433 0.216500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 432 0.216000 Disease-presents-Symptom(X,Y) <= Disease-resembles-Disease(X,A), Disease-resembles-Disease(B,A), Disease-presents-Symptom(B,Y)
# 2000 432 0.216000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 432 0.216000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 431 0.215500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 431 0.215500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-downregulates-Gene(B,Y)
# 2000 431 0.215500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-associates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 430 0.215000 Disease-localizes-Anatomy(X,Y) <= Disease-resembles-Disease(A,X), Disease-resembles-Disease(A,B), Disease-localizes-Anatomy(B,Y)
# 2000 429 0.214500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 426 0.213000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 423 0.211500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 422 0.211000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-participates-Pathway(A,B), Gene-participates-Pathway(Y,B)
# 2000 422 0.211000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 422 0.211000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 421 0.210500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 421 0.210500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,Y)
# 2000 421 0.210500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 421 0.210500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 420 0.210000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 420 0.210000 Disease-localizes-Anatomy(X,Y) <= Disease-resembles-Disease(X,A), Disease-resembles-Disease(B,A), Disease-localizes-Anatomy(B,Y)
# 2000 420 0.210000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 420 0.210000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 419 0.209500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 418 0.209000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-downregulates-Gene(B,A), Disease-downregulates-Gene(B,Y)
# 2000 418 0.209000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-downregulates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 417 0.208500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 415 0.207500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,Y)
# 2000 415 0.207500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 414 0.207000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 413 0.206500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 413 0.206500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-participates-Cellular_Component(A,B), Gene-participates-Cellular_Component(Y,B)
# 402 83 0.206468 Disease-resembles-Disease(X,Y) <= Disease-resembles-Disease(X,A), Disease-resembles-Disease(A,B), Disease-resembles-Disease(B,Y)
# 2000 412 0.206000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 411 0.205500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 411 0.205500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(Y,A)
# 892 183 0.205157 Disease-resembles-Disease(X,Y) <= Disease-resembles-Disease(A,X), Disease-resembles-Disease(A,Y)
# 2000 410 0.205000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-participates-Biological_Process(A,B), Gene-participates-Biological_Process(Y,B)
# 2000 409 0.204500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Compound-upregulates-Gene(B,A), Compound-downregulates-Gene(B,Y)
# 2000 409 0.204500 Disease-presents-Symptom(X,Y) <= Disease-resembles-Disease(A,X), Disease-resembles-Disease(A,B), Disease-presents-Symptom(B,Y)
# 2000 408 0.204000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 408 0.204000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,Y)
# 2000 408 0.204000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Compound-upregulates-Gene(B,A), Compound-upregulates-Gene(B,Y)
# 2000 408 0.204000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 407 0.203500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 407 0.203500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 407 0.203500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 406 0.203000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 406 0.203000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-regulates-Gene(B,Y)
# 1843 374 0.202930 Disease-presents-Symptom(X,Y) <= Compound-palliates-Disease(A,X), Compound-palliates-Disease(A,B), Disease-presents-Symptom(B,Y)
# 2000 404 0.202000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 404 0.202000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 402 0.201000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 401 0.200500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-downregulates-Gene(B,A), Disease-upregulates-Gene(B,Y)
# 2000 400 0.200000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 400 0.200000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(Y,A)
# 2000 399 0.199500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 399 0.199500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 399 0.199500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,Y)
# 2000 399 0.199500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 399 0.199500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-regulates-Gene(B,Y)
# 2000 398 0.199000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 398 0.199000 Disease-localizes-Anatomy(X,Y) <= Disease-resembles-Disease(A,X), Disease-resembles-Disease(B,A), Disease-localizes-Anatomy(B,Y)
# 1793 356 0.198550 Disease-presents-Symptom(X,Y) <= Disease-resembles-Disease(X,A), Disease-resembles-Disease(A,B), Disease-presents-Symptom(B,Y)
# 2000 397 0.198500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 397 0.198500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-interacts-Gene(B,Y)
# 1715 340 0.198251 Disease-presents-Symptom(X,Y) <= Disease-resembles-Disease(A,X), Disease-resembles-Disease(B,A), Disease-presents-Symptom(B,Y)
# 2000 396 0.198000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 395 0.197500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 395 0.197500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 395 0.197500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-associates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 394 0.197000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 391 0.195500 Compound-causes-Side-Effect(X,Y) <= Compound-treats-Disease(X,A), Compound-treats-Disease(B,A), Compound-causes-Side-Effect(B,Y)
# ...
# 2000 376 0.188000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-associates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 375 0.187500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-expresses-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 375 0.187500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 375 0.187500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-upregulates-Gene(B,Y)
# 2000 375 0.187500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 375 0.187500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 375 0.187500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-downregulates-Gene(B,Y)
# 2000 374 0.187000 Compound-causes-Side-Effect(X,Y) <= Compound-resembles-Compound(A,X), Compound-causes-Side-Effect(A,Y)
# 1820 340 0.186813 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 373 0.186500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-covaries-Gene(Y,B)
# 1545 288 0.186408 Disease-resembles-Disease(X,Y) <= Disease-resembles-Disease(X,A), Disease-resembles-Disease(B,A), Disease-resembles-Disease(B,Y)
# 2000 372 0.186000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 372 0.186000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-associates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 371 0.185500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 371 0.185500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(Y,A)
# 2000 371 0.185500 Anatomy-expresses-Gene(X,Y) <= Disease-localizes-Anatomy(A,X), Disease-downregulates-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 371 0.185500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 370 0.185000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-participates-Molecular_Function(A,B), Gene-participates-Molecular_Function(Y,B)
# 2000 370 0.185000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-associates-Gene(B,A), Disease-downregulates-Gene(B,Y)
# 2000 370 0.185000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 369 0.184500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Compound-binds-Gene(B,A), Compound-downregulates-Gene(B,Y)
# 2000 369 0.184500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 369 0.184500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 368 0.184000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-participates-Molecular_Function(A,B), Gene-participates-Molecular_Function(Y,B)
# 2000 368 0.184000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 366 0.183000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-regulates-Gene(Y,B)
# 2000 363 0.181500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 362 0.181000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 362 0.181000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-associates-Gene(B,A), Disease-upregulates-Gene(B,Y)
# 2000 362 0.181000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-expresses-Gene(B,Y)
# 2000 362 0.181000 Compound-causes-Side-Effect(X,Y) <= Compound-resembles-Compound(X,A), Compound-causes-Side-Effect(A,Y)
# 2000 361 0.180500 Disease-localizes-Anatomy(X,Y) <= Disease-resembles-Disease(X,A), Disease-resembles-Disease(A,B), Disease-localizes-Anatomy(B,Y)
# 2000 361 0.180500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-downregulates-Gene(B,A), Disease-upregulates-Gene(B,Y)
# 2000 361 0.180500 Anatomy-expresses-Gene(X,Y) <= Disease-localizes-Anatomy(A,X), Compound-palliates-Disease(B,A), Compound-downregulates-Gene(B,Y)
# 2000 361 0.180500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-upregulates-Gene(B,Y)
# 2000 361 0.180500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-downregulates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 359 0.179500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 359 0.179500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 359 0.179500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 359 0.179500 Gene-participates-Pathway(X,Y) <= Compound-binds-Gene(A,X), Compound-binds-Gene(A,B), Gene-participates-Pathway(B,Y)
# 2000 358 0.179000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 356 0.178000 Compound-binds-Gene(X,Y) <= Compound-resembles-Compound(X,A), Compound-resembles-Compound(B,A), Compound-binds-Gene(B,Y)
# 2000 356 0.178000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 356 0.178000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 355 0.177500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 355 0.177500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 354 0.177000 Anatomy-expresses-Gene(X,Y) <= Disease-localizes-Anatomy(A,X), Disease-upregulates-Gene(A,B), Gene-regulates-Gene(Y,B)
# 2000 354 0.177000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-interacts-Gene(B,Y)
# 871 154 0.176808 Pharmacologic_Class-includes-Compound(X,Y) <= Pharmacologic_Class-includes-Compound(X,A), Compound-resembles-Compound(A,B), Compound-resembles-Compound(B,Y)
# 2000 353 0.176500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 353 0.176500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-regulates-Gene(Y,B)
# 1033 182 0.176186 Disease-resembles-Disease(X,Y) <= Disease-resembles-Disease(A,X), Disease-resembles-Disease(A,B), Disease-resembles-Disease(B,Y)
# 2000 352 0.176000 Compound-binds-Gene(X,Y) <= Compound-binds-Gene(X,A), Compound-binds-Gene(B,A), Compound-binds-Gene(B,Y)
# 2000 351 0.175500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-covaries-Gene(Y,B)
# 2000 351 0.175500 Disease-presents-Symptom(X,Y) <= Disease-localizes-Anatomy(X,A), Disease-localizes-Anatomy(B,A), Disease-presents-Symptom(B,Y)
# 2000 351 0.175500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 350 0.175000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 349 0.174500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Disease-upregulates-Gene(B,A), Disease-associates-Gene(B,Y)
# 2000 349 0.174500 Compound-binds-Gene(X,Y) <= Compound-resembles-Compound(A,X), Compound-resembles-Compound(B,A), Compound-binds-Gene(B,Y)
# 2000 346 0.173000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Compound-binds-Gene(B,A), Compound-binds-Gene(B,Y)
# 2000 346 0.173000 Compound-causes-Side-Effect(X,Y) <= Compound-resembles-Compound(X,A), Compound-resembles-Compound(B,A), Compound-causes-Side-Effect(B,Y)
# 2000 346 0.173000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-participates-Pathway(A,B), Gene-participates-Pathway(Y,B)
# 2000 346 0.173000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-interacts-Gene(Y,B)
# 2000 345 0.172500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-covaries-Gene(Y,B)
# 528 91 0.172348 Pharmacologic_Class-includes-Compound(X,Y) <= Pharmacologic_Class-includes-Compound(X,A), Compound-resembles-Compound(B,A), Compound-resembles-Compound(Y,B)
# 2000 343 0.171500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 343 0.171500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-downregulates-Gene(B,Y)
# 2000 342 0.171000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(Y,A)
# 2000 341 0.170500 Anatomy-expresses-Gene(X,Y) <= Disease-localizes-Anatomy(A,X), Compound-palliates-Disease(B,A), Compound-upregulates-Gene(B,Y)
# 2000 341 0.170500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-participates-Pathway(A,B), Gene-participates-Pathway(Y,B)
# 2000 340 0.170000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,Y)
# 2000 340 0.170000 Anatomy-expresses-Gene(X,Y) <= Disease-localizes-Anatomy(A,X), Compound-treats-Disease(B,A), Compound-upregulates-Gene(B,Y)
# 2000 339 0.169500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-participates-Molecular_Function(A,B), Gene-participates-Molecular_Function(Y,B)
# 2000 339 0.169500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Compound-downregulates-Gene(B,A), Compound-downregulates-Gene(B,Y)
# 2000 337 0.168500 Compound-binds-Gene(X,Y) <= Compound-resembles-Compound(X,A), Compound-resembles-Compound(A,B), Compound-binds-Gene(B,Y)
# 2000 337 0.168500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,Y)
# 2000 337 0.168500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(Y,A)
# 2000 334 0.167000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-interacts-Gene(B,Y)
# 2000 333 0.166500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Anatomy-upregulates-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 333 0.166500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 332 0.166000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-participates-Cellular_Component(A,B), Gene-participates-Cellular_Component(Y,B)
# 2000 332 0.166000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 331 0.165500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,Y)
# 2000 329 0.164500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 329 0.164500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,Y)
# 2000 328 0.164000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-participates-Biological_Process(A,B), Gene-participates-Biological_Process(Y,B)
# 2000 328 0.164000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(Y,A)
# 2000 327 0.163500 Anatomy-expresses-Gene(X,Y) <= Disease-localizes-Anatomy(A,X), Disease-downregulates-Gene(A,B), Gene-regulates-Gene(B,Y)
# 2000 327 0.163500 Disease-localizes-Anatomy(X,Y) <= Disease-associates-Gene(X,A), Anatomy-expresses-Gene(Y,A)
# 2000 327 0.163500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Anatomy-downregulates-Gene(B,A), Anatomy-upregulates-Gene(B,Y)
# 2000 327 0.163500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 327 0.163500 Disease-localizes-Anatomy(X,Y) <= Disease-presents-Symptom(X,A), Disease-presents-Symptom(B,A), Disease-localizes-Anatomy(B,Y)
# 2000 326 0.163000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-covaries-Gene(Y,B)
# 2000 325 0.162500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 325 0.162500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-participates-Cellular_Component(A,B), Gene-participates-Cellular_Component(Y,B)
# 2000 324 0.162000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 323 0.161500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-covaries-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 323 0.161500 Anatomy-expresses-Gene(X,Y) <= Disease-localizes-Anatomy(A,X), Compound-treats-Disease(B,A), Compound-downregulates-Gene(B,Y)
# 2000 322 0.161000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 322 0.161000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 321 0.160500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-covaries-Gene(Y,B)
# 2000 320 0.160000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-covaries-Gene(Y,B)
# 2000 319 0.159500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-covaries-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 319 0.159500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(Y,A)
# 2000 318 0.159000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-covaries-Gene(Y,B)
# 2000 318 0.159000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-covaries-Gene(B,Y)
# 2000 318 0.159000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 318 0.159000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(B,A), Gene-covaries-Gene(Y,B)
# 2000 318 0.159000 Anatomy-upregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 317 0.158500 Anatomy-upregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-interacts-Gene(B,Y)
# 2000 317 0.158500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(A,B), Gene-covaries-Gene(B,Y)
# 2000 317 0.158500 Gene-participates-Cellular_Component(X,Y) <= Compound-binds-Gene(A,X), Compound-binds-Gene(A,B), Gene-participates-Cellular_Component(B,Y)
# 2000 316 0.158000 Disease-presents-Symptom(X,Y) <= Disease-presents-Symptom(X,A), Disease-presents-Symptom(B,A), Disease-presents-Symptom(B,Y)
# 2000 313 0.156500 Anatomy-expresses-Gene(X,Y) <= Disease-localizes-Anatomy(A,X), Disease-upregulates-Gene(A,B), Gene-interacts-Gene(Y,B)
# 2000 313 0.156500 Anatomy-downregulates-Gene(X,Y) <= Anatomy-downregulates-Gene(X,A), Gene-regulates-Gene(B,A), Gene-covaries-Gene(Y,B)
# 2000 312 0.156000 Anatomy-downregulates-Gene(X,Y) <= Anatomy-upregulates-Gene(X,A), Gene-interacts-Gene(A,B), Gene-covaries-Gene(B,Y)

# %%
# define some custom rules and check their support in the data
# here: search for symmetric relationships
rh = RulesHandler(options=opts.get("rules_handler"))
symmetric_rules = [
    "Compound-resembles-Compound(X,Y) <= Compound-resembles-Compound(Y,X)",
    "Disease-resembles-Disease(X,Y) <= Disease-resembles-Disease(Y,X)"
]
rh.calculate_predictions(rules=symmetric_rules, loader=loader_1)
# no symmetries found
print(rh.get_statistics())
# Out:
# Setting option collect_predictions to: True
# Setting option collect_statistics to: True
# Setting option num_threads to: -1
# Starting materialization of 2 rules.
# [[6486, 0], [543, 0]]

# %% [markdown]
# ## Example: drug repurposing problem

# %%
# use a new loader and a new Options instance
opts = Options()

opts.set("loader.load_u_c_rules", True)
opts.set("loader.c_min_support", 5)

loader_2 = Loader(options=opts.get("loader"))
loader_2.load_data(data=train)
loader_2.load_rules(rules=rules_target_rel)
loader_2.replace_ent_strings(entity_names)
loader_2.replace_rel_strings(relation_names)
# Out:
# Setting option load_zero_rules to: True
# Setting option z_weight to: 0.1
# Setting option z_num_unseen to: 5
# Setting option z_min_support to: -1
# Setting option z_min_preds to: -1
# Setting option z_min_conf to: 0.0001
# Setting option load_u_c_rules to: True
# Setting option c_num_unseen to: 5
# Setting option c_min_support to: 5
# Setting option c_min_preds to: -1
# Setting option c_min_conf to: 0.0001
# Setting option c_max_length to: -1
# Setting option load_b_rules to: True
# Setting option b_max_branching_factor to: -1
# Setting option b_num_unseen to: 5
# Setting option b_min_support to: -1
# Setting option b_min_preds to: -1
# Setting option b_min_conf to: 0.0001
# Setting option b_max_length to: -1
# Setting option load_u_d_rules to: True
# Setting option d_weight to: 0.01
# Setting option d_max_branching_factor to: -1
# Setting option d_num_unseen to: 5
# Setting option d_min_support to: -1
# Setting option d_min_preds to: -1
# Setting option d_min_conf to: 0.0001
# Setting option d_max_length to: -1
# Setting option load_u_xxc_rules to: True
# Setting option xxc_num_unseen to: 5
# Setting option xxc_min_support to: -1
# Setting option xxc_min_preds to: -1
# Setting option xxc_min_conf to: 0.0001
# Setting option load_u_xxd_rules to: True
# Setting option xxd_num_unseen to: 5
# Setting option xxd_min_support to: -1
# Setting option xxd_min_preds to: -1
# Setting option xxd_min_conf to: 0.0001
# Loading triples...
# Loaded triples.
# Loading rules from /home/patrick/Desktop/PyClause/local/paper-demonstration/anyburl-rules-target.txt
# Loaded 6947 rules.

# %%
# store the rules in a dict
rules_t = [rule_line.split("\t") for rule_line in loader_2.get_rules()]
rules_dict = {l[3]:l[0:3] for l in rules_t}

opts.set("qa_handler.collect_rules", True)
opts.set("qa_handler.aggregation_function", "noisyor")
opts.set("qa_handler.num_top_rules", 5)
# only output candidates that do not form a true answer in
# the loaded data
opts.set("qa_handler.filter_w_data", True)
qa = QAHandler(options=opts.get("qa_handler"))

queries = [
    ("Isoetarine", "Compound-treats-Disease"),
]

qa.calculate_answers(queries=queries, loader=loader_2, direction="tail")
answers = qa.get_answers(as_string=True)
rules = qa.get_rules(as_string=True)
print("\n-- Candidates and rules ---\n")
for i in range(10):
    print(f"Query: {queries[0]}")
    print(f"Answer {i+1}: {answers[0][i]}")
    print("Rules:")
    for rule in rules[0][i]:
        print(rule)
    print("...")
# Out:
# Setting option collect_rules to: True
#
# -- Candidates and rules ---
#
# Query: ('Isoetarine', 'Compound-treats-Disease')
# Answer 1: ('asthma', 0.44917384883476097)
# Rules:
# Compound-treats-Disease(X,asthma) <= Compound-binds-Gene(X,ADRB2)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(X,A), Compound-resembles-Compound(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-treats-Disease(A,Y)
# Compound-treats-Disease(X,asthma) <= Compound-binds-Gene(X,ADRB1)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-resembles-Compound(A,B), Compound-treats-Disease(B,Y)
# ...
# Query: ('Isoetarine', 'Compound-treats-Disease')
# Answer 2: ('hypertension', 0.4018071031819255)
# Rules:
# Compound-treats-Disease(X,hypertension) <= Compound-binds-Gene(X,ADRB2)
# Compound-treats-Disease(X,hypertension) <= Compound-binds-Gene(X,ADRB1)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-resembles-Compound(A,B), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-binds-Gene(X,A), Compound-binds-Gene(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-binds-Gene(X,A), Disease-associates-Gene(Y,A)
# ...
# Query: ('Isoetarine', 'Compound-treats-Disease')
# Answer 3: ('chronic obstructive pulmonary disease', 0.34703638983599927)
# Rules:
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(X,A), Compound-resembles-Compound(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-treats-Disease(A,Y)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-resembles-Compound(A,B), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-binds-Gene(X,A), Compound-binds-Gene(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-treats-Disease(A,B), Disease-resembles-Disease(B,Y)
# ...
# Query: ('Isoetarine', 'Compound-treats-Disease')
# Answer 4: ('glaucoma', 0.314897998683926)
# Rules:
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(X,A), Compound-resembles-Compound(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-resembles-Compound(A,B), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,glaucoma) <= Compound-binds-Gene(X,ADRB2)
# Compound-treats-Disease(X,Y) <= Compound-binds-Gene(X,A), Compound-binds-Gene(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(X,A), Compound-binds-Gene(A,B), Disease-associates-Gene(Y,B)
# ...
# Query: ('Isoetarine', 'Compound-treats-Disease')
# Answer 5: ("Crohn's disease", 0.2816707103084791)
# Rules:
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(X,A), Compound-resembles-Compound(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-resembles-Compound(A,B), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-resembles-Compound(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-binds-Gene(X,A), Compound-upregulates-Gene(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(X,A), Compound-binds-Gene(A,B), Disease-associates-Gene(Y,B)
# ...
# Query: ('Isoetarine', 'Compound-treats-Disease')
# Answer 6: ('obesity', 0.15652565426992882)
# Rules:
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-resembles-Compound(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-binds-Gene(X,A), Compound-binds-Gene(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-binds-Gene(X,A), Disease-associates-Gene(Y,A)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(X,A), Compound-binds-Gene(A,B), Disease-associates-Gene(Y,B)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-downregulates-Gene(A,B), Disease-associates-Gene(Y,B)
# ...
# Query: ('Isoetarine', 'Compound-treats-Disease')
# Answer 7: ('breast cancer', 0.13825390520684977)
# Rules:
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-resembles-Compound(A,B), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-binds-Gene(X,A), Compound-upregulates-Gene(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(X,A), Compound-binds-Gene(A,B), Disease-associates-Gene(Y,B)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-downregulates-Gene(A,B), Disease-associates-Gene(Y,B)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-binds-Gene(A,B), Disease-associates-Gene(Y,B)
# ...
# Query: ('Isoetarine', 'Compound-treats-Disease')
# Answer 8: ('ovarian cancer', 0.13571580027054775)
# Rules:
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-resembles-Compound(A,B), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(X,A), Compound-binds-Gene(A,B), Disease-upregulates-Gene(Y,B)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(X,A), Compound-upregulates-Gene(A,B), Disease-upregulates-Gene(Y,B)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-downregulates-Gene(A,B), Disease-associates-Gene(Y,B)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-binds-Gene(A,B), Disease-associates-Gene(Y,B)
# ...
# Query: ('Isoetarine', 'Compound-treats-Disease')
# Answer 9: ('peripheral nervous system neoplasm', 0.12121162392613571)
# Rules:
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-resembles-Compound(A,B), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-binds-Gene(X,A), Compound-upregulates-Gene(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-downregulates-Gene(A,B), Disease-associates-Gene(Y,B)
# ...
# Query: ('Isoetarine', 'Compound-treats-Disease')
# Answer 10: ('coronary artery disease', 0.09474672389176397)
# Rules:
# Compound-treats-Disease(X,Y) <= Compound-binds-Gene(X,A), Compound-binds-Gene(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-binds-Gene(X,A), Disease-associates-Gene(Y,A)
# Compound-treats-Disease(X,Y) <= Compound-binds-Gene(X,A), Compound-upregulates-Gene(B,A), Compound-treats-Disease(B,Y)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(X,A), Compound-binds-Gene(A,B), Disease-associates-Gene(Y,B)
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-downregulates-Gene(A,B), Disease-associates-Gene(Y,B)
# ...
# Setting option topk to: 100
# Setting option aggregation_function to: noisyor
# Setting option disc_at_least to: 10
# Setting option hard_stop_at to: -1
# Setting option num_top_rules to: 5
# Setting option filter_w_data to: True
# Setting option tie_handling to: frequency
# Setting option num_threads to: -1

# %%
# check stats of first rule
rules_dict['Compound-treats-Disease(X,asthma) <= Compound-binds-Gene(X,ADRB2)']
# Out:
# ['52', '8', '0.153846']

# %%
# analyze the first candidate more closely
opts.set("prediction_handler.collect_explanations", True)
opts.set("prediction_handler.aggregation_function", "noisyor")
opts.set("prediction_handler.num_top_rules", 5)

ph = PredictionHandler(opts.get("prediction_handler"))
triples = [
    ("Isoetarine", "Compound-treats-Disease", "asthma"),
]
ph.calculate_scores(triples=triples, loader=loader_2)
# outputs same score as above fir the first candidate
ph.get_scores(as_string=False)
targets, rules, groundings = ph.get_explanations(as_string=True)

print("\n --- Rule and grounding example --- \n")
# 3rd rule of first target triple (there is only 1)
print(rules[0][2])
# body groundings of 3rd rule of first target triple
# each grounding is a list of triples
for gr in groundings[0][2]:
    print("Next grounding:")
    for triple in gr:
        print(triple)
# Out:
# Setting option aggregation_function to: noisyor
#
#  --- Rule and grounding example ---
#
# Compound-treats-Disease(X,Y) <= Compound-resembles-Compound(A,X), Compound-treats-Disease(A,Y)
# Next grounding:
# ['Salbutamol', 'Compound-resembles-Compound', 'Isoetarine']
# ['Salbutamol', 'Compound-treats-Disease', 'asthma']
# Next grounding:
# ['Isoprenaline', 'Compound-resembles-Compound', 'Isoetarine']
# ['Isoprenaline', 'Compound-treats-Disease', 'asthma']
# Next grounding:
# ['Orciprenaline', 'Compound-resembles-Compound', 'Isoetarine']
# ['Orciprenaline', 'Compound-treats-Disease', 'asthma']
# Setting option collect_explanations to: True
# Setting option num_top_rules to: 5
# Setting option num_threads to: -1

# %% [markdown]
# ### Constraint checking

# %%
from c_clause import PredictionHandler
opts.set("prediction_handler.num_top_rules", 100)
opts.set("prediction_handler.collect_explanations", True)
opts.set("prediction_handler.aggregation_function", "noisyor")
p = PredictionHandler(opts.get("prediction_handler"))

triples =[
    ("Ibuprofen", "Compound-treats-Disease", "malaria"),
    ("Verapamil", "Compound-treats-Disease", "migraine"),
    ("Enalapril", "Compound-treats-Disease", "hypertension"),
]

rules = ["Compound-treats-Disease(X,Y) <= Compound-treats-Disease(X,A), Compound-treats-Disease(B,A), Compound-treats-Disease(B,Y)"]
stats = [(1, 1)]
print("")
loader_2.set_options(options={"b_num_unseen": "0"})
loader_2.load_rules(rules=rules, stats=stats)

p.calculate_scores(triples=triples, loader=loader_2)
scores = p.get_scores(as_string=True)
print(scores)
filtered = []
for results in scores:
    if float(results[3])>0:
        filtered.append((results[0], results[1], results[2]))


# in short
[triple for triple in scores if float(triple[3])>0.0]
# Out:
# [['Ibuprofen', 'Compound-treats-Disease', 'malaria', '0.000000'], ['Verapamil', 'Compound-treats-Disease', 'migraine', '1.000000'], ['Enalapril', 'Compound-treats-Disease', 'hypertension', '1.000000']]
# Setting option aggregation_function to: noisyor
# Setting option collect_explanations to: True
# Setting option num_top_rules to: 100
# Setting option num_threads to: -1
# Setting option b_num_unseen to: 0
# Loaded 1 rules.
# [['Verapamil', 'Compound-treats-Disease', 'migraine', '1.000000'],
#  ['Enalapril', 'Compound-treats-Disease', 'hypertension', '1.000000']]
